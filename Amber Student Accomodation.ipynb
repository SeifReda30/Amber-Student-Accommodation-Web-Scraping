# %%
import pandas as pd

# %%
import requests

def getcityresults(lat,lng,lat1,lng1,lat2,lng2):
    master_list=[]
    lat=str(lat)
    lng=str(lng)
    lat1=str(lat1)
    lng1=str(lng1)
    lat2=str(lat2)
    lng2=str(lng2)
    cookies = {
        '_gcl_au': '1.1.1867489282.1662371582',
        '_fbp': 'fb.1.1662371582027.556975202',
        '_gid': 'GA1.2.1457372563.1662663998',
        'moe_uuid': 'd59aecd2-78c5-4f1f-be7f-70e9488a08db',
        '_ga': 'GA1.2.1364241611.1662371582',
        '_ga_M5KW9Q0S5C': 'GS1.1.1662666861.4.1.1662668031.59.0.0',
    }
    headers = {
        'authority': 'base.amberstudent.com',
        'accept': '*/*',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,ar;q=0.7',
        'cache-control': 'no-cache',
        # Requests sorts cookies= alphabetically
        # 'cookie': '_gcl_au=1.1.1867489282.1662371582; _fbp=fb.1.1662371582027.556975202; _gid=GA1.2.1457372563.1662663998; moe_uuid=d59aecd2-78c5-4f1f-be7f-70e9488a08db; _ga=GA1.2.1364241611.1662371582; _ga_M5KW9Q0S5C=GS1.1.1662666861.4.1.1662668031.59.0.0',
        'origin': 'https://amberstudent.com',
        'pragma': 'no-cache',
        'referer': 'https://amberstudent.com/',
        'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
    }

    params = {
        'p': '1',
        'limit': '10',
        'methods': 'created_at,updated_at,children_count,location_coordinates,reviews_count,offers_count,features_count,videos_count,images_count,description_count',
        'region_radius': '20000',
        'sort_key': 'relevance',
        'sort_order': 'desc',
        'statuses': 'active',
        'region_lat':  lat,
        'region_lng': lng,
        'region_type': 'polygon',
        'region_bounds_lat1': lat1,
        'region_bounds_lng1': lng1,
        'region_bounds_lat2': lat2,
        'region_bounds_lng2': lng2,
    }
    response = requests.get('https://base.amberstudent.com/api/v0/inventories', params=params, cookies=cookies, headers=headers)
    pages=response.json()
    try:
        numberofpages=max(pages['data']['meta']['pages'])
    except:
        return 0
    for i in range(1,numberofpages+1):     
        cookies = {
            '_gcl_au': '1.1.1867489282.1662371582',
            '_fbp': 'fb.1.1662371582027.556975202',
            '_gid': 'GA1.2.1457372563.1662663998',
            'moe_uuid': 'd59aecd2-78c5-4f1f-be7f-70e9488a08db',
            '_ga': 'GA1.2.1364241611.1662371582',
            '_ga_M5KW9Q0S5C': 'GS1.1.1662666861.4.1.1662668031.59.0.0',
        }

        headers = {
            'authority': 'base.amberstudent.com',
            'accept': '*/*',
            'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,ar;q=0.7',
            'cache-control': 'no-cache',
            # Requests sorts cookies= alphabetically
            # 'cookie': '_gcl_au=1.1.1867489282.1662371582; _fbp=fb.1.1662371582027.556975202; _gid=GA1.2.1457372563.1662663998; moe_uuid=d59aecd2-78c5-4f1f-be7f-70e9488a08db; _ga=GA1.2.1364241611.1662371582; _ga_M5KW9Q0S5C=GS1.1.1662666861.4.1.1662668031.59.0.0',
            'origin': 'https://amberstudent.com',
            'pragma': 'no-cache',
            'referer': 'https://amberstudent.com/',
            'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-site',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
        }

        params = {
            'p': str(i),
            'limit': '10',
            'methods': 'created_at,updated_at,children_count,location_coordinates,reviews_count,offers_count,features_count,videos_count,images_count,description_count',
            'region_radius': '20000',
            'sort_key': 'relevance',
            'sort_order': 'desc',
            'statuses': 'active',
            'region_lat':  lat,
            'region_lng': lng,
            'region_type': 'polygon',
            'region_bounds_lat1': lat1,
            'region_bounds_lng1': lng1,
            'region_bounds_lat2': lat2,
            'region_bounds_lng2': lng2,
        }
        response = requests.get('https://base.amberstudent.com/api/v0/inventories', params=params, cookies=cookies, headers=headers)
        data=response.json()
        for house in data['data']['result']:
            dict={}
            try:
                house_name=house['name']
            except:
                house_name='None'
            try:
                is_available=house['available']
            except:
                is_available='None'
            try:
                deposit=house['pricing']['deposit']
            except:
                deposit='None'
            try:
                max_price=house['pricing']['max_price']
            except:
                max_price='None'
            try:
                min_price=house['pricing']['min_price']
            except:
                min_price='None'
            try:
                currency=house['pricing']['currency']
            except:
                currency='None'
            try:
                price_duration=house['pricing']['duration']
            except:
                price_duration='None'
            try:
                district=house['location']['district']['long_name']
            except:
                district='None'
            try:
                locality=house['location']['locality']['long_name']
            except:
                locality='None'
            try:
                route=house['location']['route']['long_name']
            except:
                route='None'
            try:
                postal_code=house['location']['postal_code']['long_name']
            except:
                postal_code='None'
            try:
                street_number=house['location']['street_number']['long_name']
            except:
                street_number='None'
            try:
                total_features=len(house['tags'])
            except:
                total_features='None'
            try: 
                features="/".join(house['tags'])
            except:
                features='None'
            try:
                max_area=house['meta']['max_area']
            except:
                max_area='None'
            try:
                min_area=house['meta']['min_area']
            except:
                min_area='None'
            try:
                area_unit=house['meta']['area_unit']
            except:
                area_unit='None'
            try:    
                owner_emails="/".join(house['owner']['emails'])
            except:
                owner_emails='None'
            try:
                owner_phones="/".join(house['owner']['phones'])
            except:
                owner_phones='None'
            try:
                url="https://amberstudent.com/places/"+house['canonical_name']
            except:
                url='None'
            dict['house_name']=house_name
            dict['is_available']=is_available
            dict['deposit']=deposit      
            dict['max_price']=max_price
            dict['min_price']=min_price
            dict['currency']=currency
            dict['price_duration']=price_duration
            dict['district']=district
            dict['locality']=locality
            dict['route']=route
            dict['postal_code']=postal_code
            dict['street_number']=street_number
            dict['total_features']=total_features
            dict['features']=features
            dict['max_area']=max_area
            dict['min_area']=min_area
            dict['area_unit']=area_unit
            dict['owner_emails']=owner_emails
            dict['owner_phones']=owner_phones
            dict['url']=url
            master_list.append(dict)
    return master_list

# %%
import requests

def getdata():
    result=[]
    for i in range(1,7):
        cookies = {
            '_gcl_au': '1.1.1867489282.1662371582',
            '_fbp': 'fb.1.1662371582027.556975202',
            '_gid': 'GA1.2.1457372563.1662663998',
            'moe_uuid': 'd59aecd2-78c5-4f1f-be7f-70e9488a08db',
            '_gac_UA-80947845-1': '1.1662671086.Cj0KCQjwpeaYBhDXARIsAEzItbGSh0q7Y20HLD-3m9xM7xxppaeyL_RHRryfRi12n_MwbsPvqkKjJwEaAgqBEALw_wcB',
            '_gcl_aw': 'GCL.1662671086.Cj0KCQjwpeaYBhDXARIsAEzItbGSh0q7Y20HLD-3m9xM7xxppaeyL_RHRryfRi12n_MwbsPvqkKjJwEaAgqBEALw_wcB',
            '_ga_M5KW9Q0S5C': 'GS1.1.1662675733.5.1.1662677051.21.0.0',
            '_ga': 'GA1.1.1364241611.1662371582',
        }

        headers = {
            'authority': 'base.amberstudent.com',
            'accept': '*/*',
            'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,ar;q=0.7',
            'cache-control': 'no-cache',
            # Requests sorts cookies= alphabetically
            # 'cookie': '_gcl_au=1.1.1867489282.1662371582; _fbp=fb.1.1662371582027.556975202; _gid=GA1.2.1457372563.1662663998; moe_uuid=d59aecd2-78c5-4f1f-be7f-70e9488a08db; _gac_UA-80947845-1=1.1662671086.Cj0KCQjwpeaYBhDXARIsAEzItbGSh0q7Y20HLD-3m9xM7xxppaeyL_RHRryfRi12n_MwbsPvqkKjJwEaAgqBEALw_wcB; _gcl_aw=GCL.1662671086.Cj0KCQjwpeaYBhDXARIsAEzItbGSh0q7Y20HLD-3m9xM7xxppaeyL_RHRryfRi12n_MwbsPvqkKjJwEaAgqBEALw_wcB; _ga_M5KW9Q0S5C=GS1.1.1662675733.5.1.1662677051.21.0.0; _ga=GA1.1.1364241611.1662371582',
            'origin': 'https://amberstudent.com',
            'pragma': 'no-cache',
            'referer': 'https://amberstudent.com/',
            'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-site',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
        }

        params = {
            'p': str(i),
            'limit': '100',
            'state': 'active',
            'methods': 'parent_name',
            'ancestor_id': '13',
            'sort_key': 'name',
            'sort_order': 'asc',
            'region_type':'locality'
        }

        response = requests.get('https://base.amberstudent.com/api/v0/regions', params=params, cookies=cookies, headers=headers)
        city=response.json()
        for locality in city['data']['result']:            
            coordinates=locality['location_coordinates']
            coordinates=coordinates.replace("POINT","")
            coordinates=coordinates.replace("(","")
            coordinates=coordinates.replace(")","")
            coordinates=coordinates.strip()
            lat=list(coordinates.split(" "))[1]
            lng=list(coordinates.split(" "))[0]
            lat2=locality['location']['location_bounds']['northeast']['lat']
            lng2=locality['location']['location_bounds']['northeast']['lng']
            lat1=locality['location']['location_bounds']['southwest']['lat']
            lng1=locality['location']['location_bounds']['southwest']['lng']
            returnedlist=getcityresults(lat,lng,lat1,lng1,lat2,lng2)
            if returnedlist==0:
                continue
            else:
                result.extend(returnedlist)
    return result

# %%
resultdata=getdata()

df = pd.DataFrame(resultdata)
display(df)
# Out:
#                                 house_name  is_available deposit max_price  \
# 0                          Centurion House         False     300       325
# 1                     Avon Studios, Bath\t         False     150       309
# 2                     Student Castle, Bath         False     250       379
# 3                          The Depot, Bath         False     250       319
# 4                    Charlton Court, Bath          False    None      None
# ...                                    ...           ...     ...       ...
# 1997  Vita Student Pebble Mill, Birmingham         False    None       308
# 1998                    Vita Student, York          True    None       499
# 1999                   The Boulevard, York         False     250       255
# 2000                  Student Castle York          False     150       262
# 2001                       Frederick House         False    None      None
#
# ...

# %%
df.to_csv('D:\AmberEnglandData.csv',index=False)
